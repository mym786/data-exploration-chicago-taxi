# %% [markdown]
# ## 1. 80,000 Chicago taxi trips
#
# Let's do some data explorations!

# %%
# Loading lidyverse
library(tidyverse)

# %%
taxi <- list.files(pattern = "*.csv", path="./data", 
full.names=TRUE) %>% map_df(~read_csv(., col_types = cols(
  .default = col_character(),
  trip_seconds = col_integer(),
  trip_miles = col_double(),
  pickup_community_area = col_integer(),
  dropoff_community_area = col_integer(),
  fare = col_double(),
  tips = col_double(),
  tolls = col_double(),
  extras = col_double(),
  trip_total = col_double(),
  pickup_latitude = col_double(),
  pickup_longitude = col_double(),
  dropoff_latitude = col_double(),
  dropoff_longitude = col_double()
)))
head(taxi)
# Out:
#   unique_key
# 1 bfa1a12e3724727654ac8f418dbf5b7c227ca29b
# 2 6983463bb7de10b202ec8c4a55b9068e654516b4
# 3 7e2c30c1a0193e144449b428605d0cf7fd5f87c2
# 4 d846b5158ad0d49c06a4e058b680f6a69f6ae9fd
# 5 8714a615d59bbce09dfa9087c9a7b7849b45cb93
# 6 97c691e02e3896468d1c47333950dde3a560a867
#   taxi_id
# 1 04b96cbbdcfe5b7cbb6884bc1b922819466f652662ead83eac149f6c108ce8ffd4bd7298abbe9ea2c33712f922a16f680c3543e2dbdbd929a8f1a8f44265d1ba
# 2 70115efae1503007ba9131ca674d75c15f045e364f38240d02ae75b852facaa51580191264b12f482067653c0d99cc97a4b58a093dcc9c69e793327b27480761
# 3 70115efae1503007ba9131ca674d75c15f045e364f38240d02ae75b852facaa51580191264b12f482067653c0d99cc97a4b58a093dcc9c69e793327b27480761
# 4 1d8661cf286a18a5105e132056c2aadf0b81a551e440fe24a277bd7788b745781717403d591c77238dee781850e9d9ca17c5afb07b61cf15569d98ff41caf179
# 5 a1b762f1aec578cc84bb53bb095eaf9dffd68e6ad0c27187418462087e8a9568a8d98ced316271f1c63b26edf81376ed74f30eb4869d06bbec089b7698205d61
# 6 cf176d052fcb91b2d881dd619edb887d3de0f2a9bb739b7d22a9fb4293e6b08aae93ed76f3c1ab723e398aeec09df2d7937dd6b0f41b7546a0513557a8346463
#   trip_start_timestamp    trip_end_timestamp      trip_seconds trip_miles
# 1 2013-01-10 21:15:00 UTC 2013-01-10 21:30:00 UTC   660         4.2
# 2 2013-02-13 15:15:00 UTC 2013-02-13 16:45:00 UTC  6180        11.8
# 3 2013-03-02 01:15:00 UTC 2013-03-02 01:30:00 UTC  1020         9.9
# 4 2013-01-21 13:30:00 UTC 2013-01-21 13:45:00 UTC   900         6.7
# 5 2013-01-07 07:15:00 UTC 2013-01-07 07:30:00 UTC   360         2.9
# 6 2013-01-11 14:45:00 UTC 2013-01-12 00:00:00 UTC 33060         0.0
#   pickup_census_tract dropoff_census_tract pickup_community_area
# 1 NA                  NA                   14
# 2 NA                  NA                   14
# 3 NA                  NA                   14
# 4 NA                  NA                   14
# 5 NA                  NA                   14
# 6 NA                  NA                   14
#   dropoff_community_area ⋯ extras trip_total payment_type company
# 1 NA                     ⋯ 0      11.25      Cash         NA
# 2 NA                     ⋯ 0      48.65      Cash         NA
# 3 NA                     ⋯ 0      22.05      Cash         NA
# 4 NA                     ⋯ 0      16.45      Cash         NA
# 5 NA                     ⋯ 0       8.65      Cash         NA
# 6 NA                     ⋯ 0       0.00      Cash         NA
#   pickup_latitude pickup_longitude pickup_location
# 1 41.96807        -87.72156        POINT (-87.7215590627 41.968069)
# 2 41.96807        -87.72156        POINT (-87.7215590627 41.968069)
# 3 41.96807        -87.72156        POINT (-87.7215590627 41.968069)
# 4 41.96807        -87.72156        POINT (-87.7215590627 41.968069)
# 5 41.96807        -87.72156        POINT (-87.7215590627 41.968069)
# 6 41.96807        -87.72156        POINT (-87.7215590627 41.968069)
#   dropoff_latitude dropoff_longitude dropoff_location
# 1 NA               NA                NA
# 2 NA               NA                NA
# 3 NA               NA                NA
# 4 NA               NA                NA
# 5 NA               NA                NA
# 6 NA               NA                NA

# %%
# Filter out empty columns and values

colnames(taxi)


taxi <- taxi %>% filter(!is.na(trip_start_timestamp) | trip_start_timestamp != "") %>% filter(trip_total > 0 )

# Select certain columns taxi_id, trip_seconds, trip_miles, fare, tolls, extras, trip_total, trip_start_timestamp, trip_end_timestamp,pickup_latitude, pickup_longitude
taxi <- taxi %>% select(taxi_id, trip_seconds, trip_miles, fare, tolls, extras, trip_total, trip_start_timestamp, trip_end_timestamp,pickup_latitude, pickup_longitude)

# Calculate the variance, min, and maximum fare
min(taxi$trip_total)
max(taxi$trip_total)
var(taxi$trip_total)
# Out:
#  [1] "unique_key"             "taxi_id"                "trip_start_timestamp"
#  [4] "trip_end_timestamp"     "trip_seconds"           "trip_miles"
#  [7] "pickup_census_tract"    "dropoff_census_tract"   "pickup_community_area"
# [10] "dropoff_community_area" "fare"                   "tips"
# [13] "tolls"                  "extras"                 "trip_total"
# [16] "payment_type"           "company"                "pickup_latitude"
# [19] "pickup_longitude"       "pickup_location"        "dropoff_latitude"
# [22] "dropoff_longitude"      "dropoff_location"
# [1] 0.01
# [1] 9051
# [1] 5356.094

# %% [markdown]
# ### Histogram of the fares

# %%
ggplot(taxi %>% filter(trip_total < 250), aes(x=trip_total)) + geom_histogram(bins=50)
# Out:
# plot without title

# %%
# There is huge varaince between min and maximum fares .. A good trick to remedy the effect of outliers is to use the logarithmic of logs
taxi <- taxi %>% mutate(trip_total_logarithmic=log(trip_total))

# %%
ggplot(taxi, aes(x=trip_total_logarithmic)) + geom_histogram(bins=50)
# Out:
# plot without title

# %% [markdown]
# ### Visualizing the begining of the journey

# %%
library(ggmap)
library(viridis)
#chicago <- get_map("chicago", zoom = 10, color = "bw")

chicago <- readRDS("data/chicago.rds")

# %%
# Saving the RDS for future use 
saveRDS(chicago, file = "./data/chicago.rds")

# %%
# Drawing a density map with the number of journey start locations
ggmap(chicago, darken = 0.5) +
   scale_fill_viridis(option = 'plasma') +
   geom_bin2d(data = taxi, aes(x=pickup_longitude, y=pickup_latitude), bins=50, alpha = 0.6) + labs(x='Longitude', y='Latitude', fill='Journeys')
# Out:
# Warning message:
# “Removed 47526 rows containing non-finite values (stat_bin2d).”
# plot without title

# %% [markdown]
# ### Breaking the datetime into week of day, month, and time

# %%
library('lubridate')


taxi <- taxi %>% mutate(
    trip_start_wkday=wday(trip_start_timestamp, label=TRUE, abbr=FALSE, locale = Sys.getlocale("LC_TIME")),
    trip_start_month=month(trip_start_timestamp, TRUE),
    trip_start_year=year(trip_start_timestamp),
    trip_start_week=strftime(trip_start_timestamp, format = "%W"),
    trip_start_dayofyear=yday(trip_start_timestamp),
    trip_start_time_hour=strftime(trip_start_timestamp, format = "%H")
    
)

# %% [markdown]
# ### Question 1: Peak Time of day
# #### Let's find the time of day where there are high demands of vehicles.

# %%
taxi_peak_time_of_day <- taxi %>% group_by(trip_start_year, trip_start_time_hour) %>% summarize(trips =n())
taxi_peak_time_of_day <-  taxi_peak_time_of_day %>% transform(trip_start_time_hour = as.numeric(trip_start_time_hour), trip_start_year=as.character(trip_start_year))
ggplot(taxi_peak_time_of_day, aes(x=trip_start_time_hour, y=trips, color=trip_start_year)) +  geom_point() + geom_line()
# Out:
# plot without title

# %%
ggplot(taxi_peak_time_of_day, aes(x=trip_start_time_hour, y=trips)) +  geom_point() + geom_line() + facet_wrap(~ trip_start_year)
# Out:
# plot without title

# %% [markdown]
# #### The graph shows the number of rides (y-axis) and trip start time (x-axis) for the years 2013 to 2017.
# The are two peak times from  8:30 am to 10 am and from 2 pm to 3 pm.
# We can also see the trends of numbers rides across years

# %% [markdown]
# ### Question 2: Longer routes..
#
# Trip miles can be used as indicator for passengers relying on public transports for longer distance journey's. Let's explore the the number of rides accross years. We will define a longe route as = 2 * average trip mile

# %%
long_route_threshold <- lapply(taxi[,'trip_miles'],mean, na.rm = TRUE)
long_route_threshold <- 2*long_route_threshold$trip_miles 
long_route_threshold

# The treshold is 6.9 miles about 11 Km's. That's not a long distance. Let's see the rides that are more than 100 KM's

taxi_long_routes <- taxi %>% filter(trip_miles > 60)
taxi_long_routes <- taxi_long_routes %>% mutate(trip_mins=trip_seconds/60)

# We can see that we have a trip that 18 seconds for a trip miles of 370! Something is wrong here. 

# Let's visualize the trip seconds (x-axis) and trip miles (y-axis)

ggplot(taxi_long_routes, aes(x=trip_mins, y=trip_miles)) +  geom_point() + facet_wrap(~ trip_start_year)
# Out:
# [1] 6.844918
# plot without title

# %%
# We have some outliers, let's filter them out. 
# Fun fact: Mostly average speed are between 5.50 and 39 mph. The speed limits in chicago are 70 mphs for rural high-ways.

taxi_long_routes <- taxi_long_routes %>% mutate(cab_speed=trip_miles*60*60/trip_seconds)


ggplot(taxi_long_routes, aes(x=trip_mins, y=cab_speed)) +  geom_point() + facet_wrap(~ trip_start_year)
# Out:
# plot without title

# %%
# Clearly we have some cabs with speeds of more than 20,000 miles per hour! 

taxi_long_routes_filtered_by_speed <- taxi_long_routes %>% filter(cab_speed < 120)
ggplot(taxi_long_routes_filtered_by_speed, aes(x=trip_mins, y=cab_speed)) +  geom_point() + facet_wrap(~ trip_start_year)
# Out:
# plot without title

# %%
# Let's see the number of longer routes rides increases or not
taxi_long_routes_filtered_by_speed_year <- taxi_long_routes_filtered_by_speed %>% group_by(trip_start_year) %>% summarize(no_trips=n())
head(taxi_long_routes_filtered_by_speed_year)
# Out:
#   trip_start_year no_trips
# 1 2014            1
# 2 2016            4
# 3 2017            5

# %%
# Based from the data we can see atleast there is an increase and passengers are relying on longer distance for cabs. 
# Still the numbers are less than 10, so it's not a good indicator.

# %% [markdown]
# ### Question 3: Trends of number rides per day across years

# %% [markdown]
# ### Question 4: Moving (Weekly) Average earnings of taxi drivers per month across years
#
# ### Question 5: Percentage of rides getting tips

# %% [markdown]
# ### Question 5: Average number of hours worked by drivers per day, average earning per hours per day

# %% [markdown]
# ### TOP DRIVERS

# %%
### tIPS VS FARE CORRELATION

# %%
### CAPTAIN AVAILIBILITY,

# %%
### TRIP DURATION VS GAP HOURS

# %%
### WEKKEND TRIPS

# %%
### PERCENTAGE FOR WEEKS... WEEK NUMBER

# %%
### HOW TO GET WEEK NUMBER IN R
